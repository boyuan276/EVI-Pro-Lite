# %%
import os
import sys
import numpy as np
import pandas as pd

# %%
cwd = os.getcwd()
data_dir = os.path.join(cwd, 'Population_Data')
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
df = pd.read_excel(os.path.join(data_dir, '1.xlsx'), sheet_name='Projections')
df
# Out:
# e:\anaconda3\envs\ev\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      COUNTY COUNTY_DESCR  SEXCODE SEX_DESCR  AGEGRPCODE AGEGRP_DESCR  \
# 0       1.0       Albany      0.0       All      -999.0        Total
# 1       1.0       Albany      0.0       All         0.0      Newborn
# 2       1.0       Albany      0.0       All         1.0          1.0
# 3       1.0       Albany      0.0       All         2.0          2.0
# 4       1.0       Albany      0.0       All         3.0          3.0
# ..      ...          ...      ...       ...         ...          ...
# 259     1.0       Albany      2.0    Female        82.0         82.0
# 260     1.0       Albany      2.0    Female        83.0         83.0
# 261     1.0       Albany      2.0    Female        84.0         84.0
# ...

# %%
df_all = df[df['SEX_DESCR'] == 'All']
df_all
# Out:
#     COUNTY COUNTY_DESCR  SEXCODE SEX_DESCR  AGEGRPCODE AGEGRP_DESCR  RACECODE  \
# 0      1.0       Albany      0.0       All      -999.0        Total       0.0
# 1      1.0       Albany      0.0       All         0.0      Newborn       0.0
# 2      1.0       Albany      0.0       All         1.0          1.0       0.0
# 3      1.0       Albany      0.0       All         2.0          2.0       0.0
# 4      1.0       Albany      0.0       All         3.0          3.0       0.0
# ..     ...          ...      ...       ...         ...          ...       ...
# 83     1.0       Albany      0.0       All        82.0         82.0       0.0
# 84     1.0       Albany      0.0       All        83.0         83.0       0.0
# 85     1.0       Albany      0.0       All        84.0         84.0       0.0
# 86     1.0       Albany      0.0       All        85.0          85+       0.0
# 87     1.0       Albany      0.0       All       999.0       Median       0.0
#
# ...
